# %%
from matplotlib import pyplot as plt
import numpy as np
import math

# %%
x = np.linspace(-np.pi, np.pi)

def sin(x):
    return np.sin(x)

sin_x = sin(x)
plt.figure(1)
plt.plot(sin_x, color='black')
